# %% [markdown]
# <a href="https://colab.research.google.com/github/samuca07351/VGG-16/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model
from google.colab import drive
import numpy as np

# Montar o Google Drive
drive.mount('/content/drive')

# Caminhos no Google Drive
base_dir = '/content/drive/MyDrive/classificador_ruas'
train_data_dir = os.path.join(base_dir, 'treino')
test_data_dir = os.path.join(base_dir, 'teste')
img_width, img_height = 224, 224
batch_size = 32
epochs = 50

# Gerador de dados com augmentação
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Gerador de dados para teste (sem augmentação)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

# Criar o modelo VGG16
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# Congelar as camadas da VGG16
for layer in base_model.layers:
    layer.trainable = False

# Compilar o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Treinando o modelo
model.fit(
    train_generator,
    epochs=epochs,
    steps_per_epoch=train_generator.samples // batch_size
)

# Salvar o modelo treinado
model.save('/content/drive/MyDrive/modelo_ruas_com_carros.h5')

# Função de predição
def classify_new_image(img_path, threshold=0.5):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(img_width, img_height))
    x = tf.keras.preprocessing.image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.vgg16.preprocess_input(x)

    prediction = model.predict(x)

    if prediction[0][0] > threshold:
        print(f"{img_path}: Rua sem carros!")
    else:
        print(f"{img_path}: Rua com carros!")

# Função para classificar todas as imagens de uma pasta
def classify_images_in_folder(folder_path, threshold=0.5):
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_path = os.path.join(folder_path, filename)
            classify_new_image(image_path, threshold)
            print("-" * 30)

# Teste de imagens
classify_images_in_folder(test_data_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 79 images belonging to 2 classes.
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 54s 20s/step - accuracy: 0.4792 - loss: 3.1268
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6000 - loss: 1.9505
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 53s 20s/step - accuracy: 0.5833 - loss: 0.9146
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.4667 - loss: 0.9600
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 20s/step - accuracy: 0.9574 - loss: 0.1479
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7500 - loss: 0.4995
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 11s/step - accuracy: 0.9120 - loss: 0.2875
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.7500 - loss: 0.5215
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 60s 8s/step - accuracy: 0.9508 - loss: 0.1219
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 1.0000 - loss: 0.0355
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 20s/step - accuracy: 0.9069 - loss: 0.1799
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.9062 - loss: 0.2207
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 20s/step - accuracy: 0.9494 - loss: 0.1280
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 13ms/step - accuracy: 0.9688 - loss: 0.1147
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 67s 20s/step - accuracy: 0.9792 - loss: 0.0657
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9333 - loss: 0.1438
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 51s 20s/step - accuracy: 0.9896 - loss: 0.0655
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 1.0000 - loss: 0.0432
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 62s 21s/step - accuracy: 0.9636 - loss: 0.0809
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 1.0000 - loss: 0.0146
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 22s/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step - accuracy: 1.0000 - loss: 0.0163
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 1.0000 - loss: 0.0170
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 74s 22s/step - accuracy: 1.0000 - loss: 0.0179
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 61s 21s/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 63s 11s/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 51s 21s/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 10s/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 71s 21s/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 70s 20s/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 8s/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 52s 20s/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 62s 22s/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 22s/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 1.0000 - loss: 0.0041
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 62s 20s/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 72s 20s/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 1.0000 - loss: 0.0025
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /content/drive/MyDrive/classificador_ruas/teste/sem1.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# /content/drive/MyDrive/classificador_ruas/teste/sem2.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# /content/drive/MyDrive/classificador_ruas/teste/sem3.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# /content/drive/MyDrive/classificador_ruas/teste/sem4.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# /content/drive/MyDrive/classificador_ruas/teste/sem5.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# /content/drive/MyDrive/classificador_ruas/teste/sem6.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# /content/drive/MyDrive/classificador_ruas/teste/sem7.jpg: Rua sem carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com1.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com2.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com3.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com4.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com5.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com6.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com7.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# /content/drive/MyDrive/classificador_ruas/teste/com8.jpg: Rua com carros!
# ------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /content/drive/MyDrive/classificador_ruas/teste/sem8.jpg: Rua sem carros!
# ------------------------------
